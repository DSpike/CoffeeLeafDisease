# %% [markdown]
# <a href="https://colab.research.google.com/github/DSpike/CoffeeLeafDisease/blob/main/CoffeLeafDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE=128
BATCH_SIZE=32

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory("/content/drive/MyDrive/Dataset",shuffle=True,image_size=(IMAGE_SIZE,IMAGE_SIZE),batch_size=BATCH_SIZE)
# Out:
# Found 55790 files belonging to 5 classes.

# %%
classNames= dataset.class_names

# %%
print(classNames)
# Out:
# ['Cerscospora', 'Healthy', 'Leaf rust', 'Miner', 'Phoma']

# %%
len(dataset)
# Out:
# 1744

# %%
for image_batch, label_batch in dataset.take(1):
    #for i in range(15):
       # ax=plt.subplot(3,5,i+1)
        plt.imshow(image_batch[0].numpy().astype("uint8"))
        plt.title(classNames[label_batch[0]])

# %%
train_size=0.8
len(dataset)*train_size
# Out:
# 1395.2

# %%
train_ds=dataset.take(1395)

# %%
val_size=0.1
len(dataset)*val_size
# Out:
# 174.4

# %%
val_ds=dataset.take(174)

# %%
test_size=0.1
len(dataset)*test_size
# Out:
# 174.4

# %%
test_ds=dataset.take(174)

# %%
len(test_ds)
# Out:
# 174

# %%
# Out:
#   File "<ipython-input-54-24517afc065f>", line 1
#     len(train_ds,,val_ds,test_ds)
#                  ^
# SyntaxError: invalid syntax
